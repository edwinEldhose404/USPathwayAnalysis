# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('output_file.xlsx',index_col=0)

# %%
numeric_df = df.select_dtypes(include='number')

print(numeric_df)
# Out:
#         10th Percentage   12th Percentange  UG - CGPA (out of 10)   \
# S. No.
# 1                   0.00              0.00                   70.99
# 2                   0.00              0.00                   79.50
# 3                   0.00              0.00                   78.70
# 4                   0.00              0.00                  100.00
# 5                   0.00              0.00                   74.20
# ...                  ...               ...                     ...
# 311                75.83             65.69                   87.10
# 312                81.70             90.60                   59.00
# 313                91.20             67.33                   93.80
# 314                 0.00              0.00                   65.00
# 315                 0.00              0.00                   65.00
#
#         GPA (Out of 4)  PG - CGPA or %  Work Exp.  noopt  UniScore
# S. No.
# 1                70.75             0.0        3.0      1     70.99
# 2                79.50             0.0        1.0      1     79.50
# 3                78.50             0.0        2.0      1     78.70
# 4               100.00             0.0        1.0      1    100.00
# 5                74.00             0.0        3.0      1     74.20
# ...                ...             ...        ...    ...       ...
# 311              87.00             0.0        2.0      1     87.10
# 312               0.00             0.0        0.0      0     59.00
# 313              93.75             0.0        2.0      1     93.80
# 314              70.00             0.0        0.0      0     65.00
# 315              70.00             0.0        0.0      0     65.00
#
# [315 rows x 8 columns]

# %%
numeric_df.corr()
# Out:
#                         10th Percentage   12th Percentange  \
# 10th Percentage                 1.000000          0.896074
# 12th Percentange                0.896074          1.000000
# UG - CGPA (out of 10)           0.102644          0.097252
# GPA (Out of 4)                  0.026939          0.000176
# PG - CGPA or %                 -0.047632         -0.045862
# Work Exp.                      -0.073997         -0.101148
# noopt                           0.120854          0.158481
# UniScore                       -0.005594         -0.005971
#
#                         UG - CGPA (out of 10)   GPA (Out of 4)  \
# 10th Percentage                       0.102644        0.026939
# 12th Percentange                      0.097252        0.000176
# UG - CGPA (out of 10)                 1.000000        0.783035
# GPA (Out of 4)                        0.783035        1.000000
# PG - CGPA or %                        0.028751        0.007669
# Work Exp.                            -0.263330       -0.210951
# noopt                                 0.165395        0.051745
# UniScore                              0.397822        0.297885
#
#                         PG - CGPA or %  Work Exp.     noopt  UniScore
# 10th Percentage              -0.047632  -0.073997  0.120854 -0.005594
# 12th Percentange             -0.045862  -0.101148  0.158481 -0.005971
# UG - CGPA (out of 10)         0.028751  -0.263330  0.165395  0.397822
# GPA (Out of 4)                0.007669  -0.210951  0.051745  0.297885
# PG - CGPA or %                1.000000   0.316880  0.082538  0.928521
# Work Exp.                     0.316880   1.000000  0.054259  0.193036
# noopt                         0.082538   0.054259  1.000000  0.137190
# UniScore                      0.928521   0.193036  0.137190  1.000000
